# %% [markdown]
# # Lectura de datos desde la base de datos
#
# En esta lección aprenderas a como leer queries SQL y tablas de bases de datos relacionales dentro objetos *DataFrame* usando pandas. Tambien veremos diferentes técnicas para persistir objetos DataFrame a tablas de bases de datos
#
# ### Vincular Jupyter con Postgres
#
# Instalar sqlalchemy
#
# ~~~python
# %pip install sqlalchemy
# ~~~
#
# ![image.png](attachment:1da66987-a77b-4f83-8cf0-03924d99b49c.png)
#
# Si la conexión es correcta aparecera el siguiente mensaje:
#
# ![image.png](attachment:4ec7e3b4-a2df-476a-9c01-c28fcc360e42.png)

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql://postgres:pgadmin1325@localhost:25432/tauranet_db")

print(engine)
# Out:
# Engine(postgresql://postgres:***@localhost:25432/tauranet_db)

# %%
import pandas as pd

df = pd.read_sql("SELECT * FROM clientes;", engine)

df.head()
# Out:
#    id_cliente nombre_completo   dni  id_cajero          created_at  \
# 0         172          Tejada  None         36 2025-10-10 11:01:07
# 1         173           Ortiz  None         36 2025-10-10 11:08:04
# 2         174       Velasquez  None         36 2025-10-13 14:59:31
# 3         175            None  None         36 2025-10-14 12:55:51
# 4         176            None  None         36 2025-10-14 13:04:22
#
#            updated_at id_mozo  id_restaurant
# 0 2025-10-10 11:01:07    None             50
# 1 2025-10-10 11:08:04    None             50
# 2 2025-10-13 14:59:31    None             50
# 3 2025-10-14 12:55:51    None             50
# 4 2025-10-14 13:04:22    None             50
