# %% [markdown]
# # Bibliografía

# %% [markdown]
# - Curso de FreeCodeCamp (https://www.freecodecamp.org/learn/data-analysis-with-python/)
# - Recursos FreeCodeCamp (https://github.com/krishnatray/RDP-Reading-Data-with-Python-and-Pandas/tree/master/unit-1-reading-data-with-python-and-pandas)
# - Ejercicios Pandas (https://labex.io/es/exercises/pandas)
# - Documentación Pandas (https://pandas.pydata.org/docs/getting_started/index.html#getting-started)
