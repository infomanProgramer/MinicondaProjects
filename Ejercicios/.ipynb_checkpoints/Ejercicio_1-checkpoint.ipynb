# %%
import pandas as pd

# %%
data = {"USA": 330000000, "China": 1400000000, "India": 1300000000}

# %%
paises_poblacion = pd.Series(data)

# %%
paises_poblacion.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 3 entries, USA to India
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 3 non-null      int64
# dtypes: int64(1)
# memory usage: 48.0+ bytes

# %%
paises_poblacion = paises_poblacion.sort_index() # Ordena alfabeticamente

# %%
paises_poblacion
# Out:
# China    1400000000
# India    1300000000
# USA       330000000
# dtype: int64

# %%
new_index = ["USA", "Canada", "Mexico", "China", "Japan", "India", "Russia"]

# %%
paises_poblacion = paises_poblacion.reindex(new_index)

# %%
paises_poblacion
# Out:
# USA       3.300000e+08
# Canada             NaN
# Mexico             NaN
# China     1.400000e+09
# Japan              NaN
# India     1.300000e+09
# Russia             NaN
# dtype: float64

# %%
paises_poblacion = paises_poblacion.fillna(0)

# %%
paises_poblacion
# Out:
# USA       3.300000e+08
# Canada    0.000000e+00
# Mexico    0.000000e+00
# China     1.400000e+09
# Japan     0.000000e+00
# India     1.300000e+09
# Russia    0.000000e+00
# dtype: float64
