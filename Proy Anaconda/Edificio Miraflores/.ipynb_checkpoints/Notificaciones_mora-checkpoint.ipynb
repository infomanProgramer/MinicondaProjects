# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from reportlab.pdfgen import canvas
from reportlab.platypus import Table, TableStyle
from reportlab.lib import colors
# %matplotlib inline

# %%
df = pd.read_csv(
    '../data/MoraJulio.csv',
    sep=';',
    decimal=',',
    encoding='cp1252'
)

# %%
df['JULIO'] = df['JULIO'].fillna('')
df['AGOSTO'] = df['AGOSTO'].fillna('')
df['SEPTIEMBRE'] = df['SEPTIEMBRE'].fillna('')
df['OCTUBRE'] = df['OCTUBRE'].fillna('')
df['NOVIEMBRE'] = df['NOVIEMBRE'].fillna('')
df['DICIEMBRE'] = df['DICIEMBRE'].fillna('')
df['ENERO'] = df['ENERO'].fillna('')
df['FEBRERO'] = df['FEBRERO'].fillna('')
df['MARZO'] = df['MARZO'].fillna('')
df['ABRIL'] = df['ABRIL'].fillna('')
df['MAYO'] = df['MAYO'].fillna('')
df['JUNIO'] = df['JUNIO'].fillna('')
df['PISO'] = df['PISO'].astype('Int64')

# %%
df
# Out:
#     LETRA  PISO           NOMBRE Y APELLIDO   JULIO  AGOSTO SEPTIEMBRE  \
# 0       A     3       JESMY AMANDA PALENQUE  154.05  154.03
# 1       B     3   NATHALIE CASTRO INOFUENTE          191.44
# 2       C     3       JOSE MANUEL BUSTILLOS  157.48  163.53
# 3       D     3  ABDON FELIPE SERNA OLAÑETA   92.91   94.17
# 4       E     3      JULIETA MAMANI DE NINA  268.06  238.98
# ..    ...   ...                         ...     ...     ...        ...
# 103     C    21                 CIDAL LTDA,  191.96  191.49
# 104     B    22        FABIOLA LAURA VARGAS   317.0   317.0
# 105     C    22                 CIDAL LTDA,    90.0    90.0
# 106    AC  <NA>                  LAVANDERIA   46.16   45.07
# 107   NaN  <NA>                    GIMNASIO    0.48    0.05
#
#     OCTUBRE NOVIEMBRE DICIEMBRE ENERO FEBRERO MARZO ABRIL MAYO JUNIO
# 0
# 1
# 2
# 3
# 4
# ..      ...       ...       ...   ...     ...   ...   ...  ...   ...
# 103
# 104
# 105
# 106
# 107
#
# [108 rows x 15 columns]

# %%
def generateTable(data):
    table = Table(data)
    # Definimos los estilos que queremos aplicar.
    # La lista de estilos contiene tuplas que especifican qué hacer.
    style = TableStyle([
        # Estilo para la fila de encabezados (fila 0, todas las columnas)
        ('BACKGROUND', (0, 0), (-1, 0), colors.grey),          # Fondo gris
        ('TEXTCOLOR', (0, 0), (-1, 0), colors.whitesmoke),     # Texto blanco
        ('FONTNAME', (0, 0), (-1, 0), 'Helvetica-Bold'),       # Fuente en negrita
        ('FONTSIZE', (0, 0), (-1, 0), 12),                     # Tamaño de fuente
        ('ALIGN', (0, 0), (-1, 0), 'CENTER'),                  # Alineación centrada
    
        # Estilo para el resto de las filas (de la 1 en adelante)
        ('BACKGROUND', (0, 1), (-1, -1), colors.beige),        # Fondo beige
        ('FONTNAME', (0, 1), (-1, -1), 'Helvetica'),
        ('FONTSIZE', (0, 1), (-1, -1), 10),
        ('ALIGN', (2, 1), (-1, -1), 'CENTER'),                 # Centrar columnas de montos
    
        # Estilo para toda la tabla
        ('GRID', (0, 0), (-1, -1), 1, colors.black),           # Poner una cuadrícula negra
        ('VALIGN', (0, 0), (-1, -1), 'MIDDLE'),                # Alineación vertical media
    ])
    # Aplicamos los estilos a la tabla.
    table.setStyle(style)

# %%
def formato_notificacion_mora(floor, 
                    number_of_department, 
                    user_name, 
                    current_date,
                    montos_x_mes,
                    total_adeudado,
                    fecha_corte):
    building_name = "Edificio Miraflores Norte"
    city_date = "La Paz, "+current_date
    departatment = "Departamento "+str(floor)+str(number_of_department)
    font_bold_style = "Helvetica-Bold"
    font_normal_style = "Helvetica"
    font_normal_size = 11
    font_medium_size = 12
    font_big_size = 16
    interlineado = 580
    parrafo = [
        "Por medio de la presente, la Administración del "+building_name+" se dirige a usted",
        "para comunicarle que, de acuerdo con nuestros registros administrativos,",
        "el departamento "+str(floor)+str(number_of_department)+" presenta un saldo pendiente correspondiente al",
        "pago de expensas comunes, con corte al "+fecha_corte
    ]
    parrafo2 = [
        "Por tal motivo, solicitamos regularizar el saldo pendiente a la brevedad posible, a fin de",
        "mantener al día las obligaciones correspondientes a la unidad y contribuir al normal",
        "funcionamiento y mantenimiento de las áreas y servicios comunes del edificio."
    ]
    parrafo3 = [
        "En caso de que el pago ya hubiera sido efectuado, agradeceremos presentar o enviar el",
        "correspondiente comprobante a la Administración para realizar la verificación y",
        "actualización de nuestros registros."
    ]
    
    # Título
    pdf.setFont(font_bold_style, font_big_size)
    pdf.drawCentredString(300, 780, building_name)
    
    # Subtítulo
    pdf.setFont(font_normal_style, font_normal_size)
    pdf.drawCentredString(300, 760, "ADMINISTRACIÓN")
    
    # Fecha
    pdf.drawString(370, 720, city_date)
    
    # Destinatario
    pdf.setFont(font_bold_style, font_normal_size)
    pdf.drawString(80, 680, "Señor(a):")
    
    pdf.setFont(font_normal_style, font_normal_size)
    pdf.drawString(80, 665, user_name)
    pdf.drawString(80, 650, departatment)
    pdf.drawString(80, 635, 'Presente.-')
    
    # Referencia
    pdf.setFont(font_bold_style, font_normal_size)
    pdf.drawString(80, 600, "REF.: NOTIFICACIÓN DE MORA POR EXPENSAS")
    
    # Texto
    pdf.setFont(font_normal_style, font_normal_size)

    for linea in parrafo:
        interlineado = interlineado - 15
        pdf.drawString(
            80,
            interlineado,
            linea
        )
    
    # Datos de la deuda
    interlineado = interlineado - 20
    pdf.setFont(font_bold_style, font_normal_size)
    pdf.drawString(80, interlineado, "DETALLE DE LA DEUDA")

    interlineado = interlineado - 20
    pdf.setFont(font_normal_style, font_normal_size)
    pdf.drawString(80, interlineado, "Períodos adeudados:")

    tabla = Table(montos_x_mes)
    tabla.setStyle(TableStyle([
        # dibuja una cuadricula desde la primera cuadricula arriba a la izquierda hasta la última fila y columna de color negro con grosor 1
        ("GRID", (0, 0), (-1, -1), 1, colors.black), 
        ("BACKGROUND", (0, 0), (-1, 0), colors.lightgrey),
        ("ALIGN", (1, 0), (-1, -1), "CENTER"),
        ("FONTNAME", (0, 0), (-1, 0), "Helvetica-Bold"),
        ("FONTNAME", (-1, 0), (-1, -1), "Helvetica-Bold"),
    ]))
    interlineado = interlineado - 50
    tabla.wrapOn(pdf, 500, 100)
    tabla.drawOn(pdf, 80, interlineado)

    interlineado = interlineado - 20
    pdf.setFont(font_bold_style, font_medium_size)
    pdf.drawString(80, interlineado, f"TOTAL ADEUDADO: Bs. {total_adeudado}")

    interlineado = interlineado - 20
    pdf.setFont(font_normal_style, font_normal_size)
    for linea2 in parrafo2:
        pdf.drawString(
            80,
            interlineado,
            linea2
        )
        interlineado = interlineado - 15
    interlineado = interlineado - 5

    for linea3 in parrafo3:
        pdf.drawString(
            80,
            interlineado,
            linea3
        )
        interlineado = interlineado - 15

    # Firma
    interlineado = interlineado - 20
    pdf.setFont("Helvetica", 11)
    pdf.drawString(80, interlineado, "Atentamente,")
    interlineado = interlineado - 80
    pdf.drawString(80, interlineado, "____________________________")
    interlineado = interlineado - 15
    pdf.drawString(80, interlineado, "Administrador")
    interlineado = interlineado - 15
    pdf.drawString(80, interlineado, "Edif. " + building_name)
    pdf.showPage()

# %%
pdf = canvas.Canvas("carta_mora9.pdf")
current_date = '4 de septiembre de 2026'
debe_julio = False
debe_agosto = False
meses_de_mora = 2
fecha_corte = "31 de agosto 2026"

for indice, fila in df.iterrows():
    numero_meses_adeudados = 0
    montos_x_mes = [['Concepto', 'Expensas']]
    monto_adeudado = 0
    for nombre_mes, monto in fila.iloc[3:14].items():
        if str(monto).strip() != "":
            numero_meses_adeudados = numero_meses_adeudados + 1
            monto_adeudado = monto_adeudado + monto
            montos_x_mes.append([nombre_mes, monto])
    
    if numero_meses_adeudados >= meses_de_mora:
        monto_adeudado = round(monto_adeudado, 2)
        montos_x_mes.append(['Total', monto_adeudado])
        print(f"{str(indice)} El copropieatario {fila["LETRA"]}{fila["PISO"]} - {fila["NOMBRE Y APELLIDO"]} tiene dos meses de duda, meses adeudados {str(numero_meses_adeudados)}")
        print(montos_x_mes)
        formato_notificacion_mora(fila["PISO"], fila["LETRA"], fila["NOMBRE Y APELLIDO"], current_date, [list(x) for x in zip(*montos_x_mes)], monto_adeudado, fecha_corte)
    
# Guardar
pdf.save()
# Out:
# 0 El copropieatario A3 - JESMY AMANDA PALENQUE tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 154.05], ['AGOSTO', 154.03], ['Total', 308.08]]
# 2 El copropieatario C3 - JOSE MANUEL BUSTILLOS tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 157.48], ['AGOSTO', 163.53], ['Total', 321.01]]
# 3 El copropieatario D3 - ABDON FELIPE SERNA OLAÑETA tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO',
iene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 236.91], ['AGOSTO', 241.35], ['Total', 478.26]]
# 78 El copropieatario A16 - PABEL SAINZ E,/ERICK JARANDILLA tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 180.63], ['AGOSTO', 177.85], ['Total', 358.48]]
# 80 El copropieatario C16 - ROSMERY MAMANI tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 219.89], ['AGOSTO', 203.48], ['Total', 423.37]]
# 82 El copropieatario E16 - CIDAL LTDA. tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 236.0], ['AGOSTO', 236.0], ['Total', 472.0]]
# 87 El copropieatario DE17 - CIDAL LTDA, tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 333.05], ['AGOSTO', 333.03], ['Total', 666.08]]
# 89 El copropieatario AF18 - CIDAL LTDA, tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 287.0], ['AGOSTO', 287.0], ['Total', 574.0]]
# 91 El copropieatario C18 - SANDRA MALLEA tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 145.29], ['AGOSTO', 145.33], ['Total', 290.62]]
# 92 El copropieatario DE18 - CARLA JIMENEZ/SANDRO MEDRANO tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 491.23], ['AGOSTO', 514.97], ['Total', 1006.2]]
# 93 El copropieatario AF19 - CIDAL LTDA, tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 287.0], ['AGOSTO', 287.0], ['Total', 574.0]]
# 94 El copropieatario B19 - SERGIO ALIAGA RIOS tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 187.72], ['AGOSTO', 183.49], ['Total', 371.21]]
# 95 El copropieatario C19 - ANDREA PACSI COPANA tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 233.1], ['AGOSTO', 234.1], ['Total', 467.2]]
# 96 El copropieatario DE19 - CIDAL LTDA, tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 333.0], ['AGOSTO', 333.0], ['Total', 666.0]]
# 97 El copropieatario AF20 - CIDAL LTDA, tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 287.0], ['AGOSTO', 287.03], ['Total', 574.03]]
# 98 El copropieatario B20 - RAQUEL GUTIERREZ FLORES tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 228.7], ['AGOSTO', 231.79], ['Total', 460.49]]
# 99 El copropieatario C20 - CATHERIN ROJAS C,/MIGUELA,CORONADO tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 145.0], ['AGOSTO', 145.0], ['Total', 290.0]]
# 100 El copropieatario DE20 - GRACE FERNANDEZ tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 407.27], ['AGOSTO', 407.37], ['Total', 814.64]]
# 101 El copropieatario A21 - CIDAL LTDA, tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 539.48], ['AGOSTO', 539.68], ['Total', 1079.16]]
# 102 El copropieatario B21 - ROLY CHAVEZ HUANCA tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 144.53], ['AGOSTO', 144.32], ['Total', 288.85]]
# 103 El copropieatario C21 - CIDAL LTDA, tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 191.96], ['AGOSTO', 191.49], ['Total', 383.45]]
# 104 El copropieatario B22 - FABIOLA LAURA VARGAS tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 317.0], ['AGOSTO', 317.0], ['Total', 634.0]]
# 105 El copropieatario C22 - CIDAL LTDA, tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 90.0], ['AGOSTO', 90.0], ['Total', 180.0]]
# 106 El copropieatario AC<NA> - LAVANDERIA tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 46.16], ['AGOSTO', 45.07], ['Total', 91.23]]
# 107 El copropieatario nan<NA> - GIMNASIO tiene dos meses de duda, meses adeudados 2
# [['Concepto', 'Expensas'], ['JULIO', 0.48], ['AGOSTO', 0.05], ['Total', 0.53]]
